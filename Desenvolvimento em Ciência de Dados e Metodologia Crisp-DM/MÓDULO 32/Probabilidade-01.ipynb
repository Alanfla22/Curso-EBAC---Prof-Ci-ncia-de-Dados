# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Probabilidade - Tarefa

# %%
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt
import math

# %% [markdown]
# 1. Uma máquina embala ração para cachorro em pacotes de 15 kg, mas cada pacote produzido acaba tendo um peso aleatório, com distribuição Normal, com média 15kg, mas com desvio padrão 0,1 kg. Obtenha a probabilidade de que um pacote selecionado aleatoriamente dessa produção tenha mais que 15,2 kg.

# %%
prob = 1 - stats.norm.cdf (15.2, loc = 15, scale = 1)

print(f'A probabilidade de que um pacote selecionado aleatoriamente tenha mais que 15,2 kg é de {prob:.2%}'.replace('.',','))
# Out:
# A probabilidade de que um pacote selecionado aleatoriamente tenha mais que 15,2 kg é de 42,07%

# %% [markdown]
# 2. Da máquina descrita acima, obtenha o percentil de ordem 95% para o peso dos pacotes. Ou seja, o valor tal que a probabilidade de um pacote ter peso menor que este seja de 95%.

# %%
perc = stats.norm.ppf(0.95, loc=15, scale=1)

print(f'O valor tal que a probabilidade de um pacote ter peso menor que este seja de 95% é de {perc:.2f} Kg'.replace('.',','))
# Out:
# O valor tal que a probabilidade de um pacote ter peso menor que este seja de 95% é de 16,64 Kg

# %% [markdown]
# 3. Suponha duas variáveis aleatórias $Y_1$ e $Y_2$, a primeira com distribuição Normal Padrão (média=0, variância=1), a segunda com distribuição *t-studdent* com 5 graus de liberdade (também padrão). Calcule, para cada uma, a probabilidade de ser menor que cada um dos valores contidos no objeto $Y$ na célula abaixo:

# %%
Y=np.linspace(-6, 6, 200)
# Seu código começa aqui

# definindo a média e a variância

mu = 0
variance = 1

# encontrando o desvio da padrão

sigma = math.sqrt(variance)

# encontrando as probabilidades dos valores na distribuição Normal
y = stats.norm.pdf(Y, mu, sigma)

# encontrando as probabilidades dos valores na distribuição t-studdent
t = stats.t.pdf(Y, 5)

print(y)
print(t)
# Out:
# [6.07588285e-09 8.70866244e-09 1.24369621e-08 1.76969307e-08
#  2.50900991e-08 3.54427647e-08 4.98854154e-08 6.99584826e-08
#  9.77525189e-08 1.36093167e-07 1.88784125e-07 2.60924830e-07
#  3.59323924e-07 4.93034881e-07 6.74046635e-07 9.18169857e-07
#  1.24616889e-06 1.68520045e-06 2.27063336e-06 3.04833891e-06
#  4.07755917e-06 5.43448109e-06 7.21666721e-06 9.54852002e-06
#  1.25879855e-05 1.65347333e-05 2.16400838e-05 2.82189904e-05
#  3.66644177e-05 4.74644989e-05 6.12228855e-05 7.86827403e-05
#  1.00754847e-04 1.28550332e-04 1.63418510e-04 2.06990340e-04
#  2.61227982e-04 3.28480884e-04 4.11548756e-04 5.13751701e-04
#  6.39007624e-04 7.91916868e-04 9.77853816e-04 1.20306492e-03
#  1.47477233e-03 1.80128189e-03 2.19209400e-03 2.65801514e-03
#  3.21126773e-03 3.86559514e-03 4.63635846e-03 5.54062085e-03
#  6.59721512e-03 7.82678937e-03 9.25182553e-03 1.08966251e-02
#  1.27872564e-02 1.49514572e-02 1.74184882e-02 2.02189307e-02
#  2.33844249e-02 2.69473456e-02 3.09404110e-02 3.53962253e-02
#  4.03467550e-02 4.58227404e-02 5.18530484e-02 5.84639717e-02
#  6.56784847e-02 7.35154670e-02 8.19889083e-02 9.11071108e-02
#  1.00871907e-01 1.11277914e-01 1.22311843e-01 1.33951885e-01
#  1.46167203e-01 1.58917539e-01 1.72152967e-01 1.85813806e-01
#  0.0633681  0.06867005 0.07439151 0.0805566  0.08718878 0.09431025
#  0.10194136 0.11009986 0.11880004 0.12805181 0.13785966 0.14822152
#  0.15912758 0.17055908 0.18248709 0.19487132 0.20765914 0.22078463
#  0.23416803 0.24771541 0.26131888 0.27485713 0.28819667 0.30119358
#  0.31369586 0.32554642 0.33658654 0.34665984 0.35561648 0.36331752
#  0.36963922 0.37447707 0.3777493  0.37939971 0.37939971 0.3777493
#  0.37447707 0.36963922 0.36331752 0.35561648 0.34665984 0.33658654
#  0.32554642 0.31369586 0.30119358 0.28819667 0.27485713 0.26131888
#  0.24771541 0.23416803 0.22078463 0.20765914 0.19487132 0.18248709
#  0.17055908 0.15912758 0.14822152 0.13785966 0.12805181 0.11880004
#  0.11009986 0.10194136 0.09431025 0.08718878 0.0805566  0.07439151
#  0.06867005 0.0633681  0.05846125 0.05392526 0.04973625 0.04587103
#  0.0423072  0.03902331 0.03599895 0.03321479 0.03065259 0.02829527
#  0.02612683 0.02413234 0.02229794 0.02061076 0.01905887 0.01763127
#  0.01631779 0.01510907 0.0139965  0.01297215 0.01202874 0.0111596
#  0.01035859 0.0096201  0.00893899 0.00831053 0.00773041 0.00719468
#  0.00669971 0.00624219 0.00581909 0.00542762 0.00506525 0.00472964
#  0.00441867 0.00413038 0.00386297 0.00361481 0.0033844  0.00317035
#  0.00297141 0.0027864  0.00261426 0.00245402 0.00230478 0.00216571
#  0.00203605 0.00191511 0.00180223 0.00169683 0.00159837 0.00150634
#  0.00142028 0.00133976 0.00126439 0.0011938  0.00112767 0.00106567
#  0.00100753 0.00095298 0.00090177 0.00085367 0.00080849 0.00076601
#  0.00072606 0.00068848]

# %% [markdown]
# 4. Faça uma visualização gráfica dos dados do item anterior.

# %%
fig, ax = plt.subplots(figsize=(10,4))

y = stats.norm.pdf(Y, mu, sigma)

ax.plot(Y, y, label='Normal')

for gl in ([5]):
    t = stats.t.pdf(Y, gl)
    ax.plot(Y, t, label=f't({gl})');

plt.show()

# %% [markdown]
# 5. 3. Suponha duas variáveis aleatórias $Y_1$ e $Y_2$, a primeira com distribuição Normal Padrão (média=0, variância=1), a segunda com distribuição *t-studdent* com 5 graus de liberdade (também padrão). Calcule, para cada uma, o percentil (a inversa da *CDF*) para cada um dos valores do objeto *P* abaixo:

# %%
Y=np.linspace(0, 1, 20)
# Seu código começa aqui

# definindo a média e a variância

mu = 0
variance = 1

# encontrando o desvio da padrão

sigma = math.sqrt(variance)

# apurando o percentil dos valores na distribuição normal

stats.norm.ppf(Y, loc=0, scale=1)

# apurando o percentil dos valores na distribuição t-studdent com 5 graus de liberdade

stats.t(5).ppf(Y)
# Out:
# array([       -inf, -1.97489346, -1.4358593 , -1.11439619, -0.87612441,
#        -0.68067217, -0.51027663, -0.35532778, -0.20979907, -0.06939058,
#         0.06939058,  0.20979907,  0.35532778,  0.51027663,  0.68067217,
#         0.87612441,  1.11439619,  1.4358593 ,  1.97489346,         inf])

# %% [markdown]
# 6. Faça um gráfico com os dados do item anterior.

# %%
fig, ax = plt.subplots(figsize=(10,4))

y = stats.norm.ppf(Y, loc=mu, scale=sigma)

ax.plot(y, Y, label='Normal')

for gl in ([5]):
    t = stats.t.ppf(Y, gl)
    ax.plot(t, Y, label=f't({gl})');

plt.show()
